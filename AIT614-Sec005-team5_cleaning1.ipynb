# %%
import pandas as pd 
import numpy as np
import datetime
import matplotlib.pyplot as plt 
from pandas.api.types import CategoricalDtype

# %%
austin_df= pd.read_csv('C:/Users/bharg/OneDrive/Documents/SPRING 2024/AIT 614/PROJECT/listings.csv')
austin_df
# Out:
#                  id                                         name      host_id  \
# 0      3.291720e+05          Hillside designer home,10 min.dwntn    1680871.0
# 1      3.293060e+05       Urban Homestead, 5 minutes to downtown     880571.0
# 2      3.315490e+05               One Room with Private Bathroom    1690383.0
# 3      3.338150e+05                Solar Sanctuary - Austin Room     372962.0
# 4      3.334420e+05                   Rare Secluded 1940s Estate    1698318.0
# ...             ...                                          ...          ...
# 13803  7.750000e+17  Downtown Austin Pied de Terre, cute studio!   95139463.0
# 13804  7.750000e+17                   Bedroom W/ Shared Bathroom  286256623.0
# 13805  7.750000e+17                                    Creek Zen  490347286.0
# 13806  7.750000e+17              The Flamingo - 1/1 pink retreat  203862347.0
# 13807  7.750000e+17                  Majic School Bus / Schoolie   23148741.0
#
# ...

# %%
austin_df.head()
# Out:
#          id                                    name    host_id host_name  \
# 0  329172.0     Hillside designer home,10 min.dwntn  1680871.0     Janet
# 1  329306.0  Urban Homestead, 5 minutes to downtown   880571.0     Angel
# 2  331549.0          One Room with Private Bathroom  1690383.0    Sandra
# 3  333815.0           Solar Sanctuary - Austin Room   372962.0       Kim
# 4  333442.0              Rare Secluded 1940s Estate  1698318.0  Virginia
#
#    neighbourhood_group  neighbourhood  latitude  longitude        room_type  \
# 0                  NaN        78746.0  30.30085  -97.80794  Entire home/apt
# 1                  NaN        78702.0  30.27232  -97.72579     Private room
# 2                  NaN        78725.0  30.23911  -97.58625     Private room
# 3                  NaN        78704.0  30.25381  -97.75262     Private room
# 4                  NaN        78703.0  30.31267  -97.76641  Entire home/apt
#
# ...

# %%
austin_df.tail()
# Out:
#                  id                                         name      host_id  \
# 13803  7.750000e+17  Downtown Austin Pied de Terre, cute studio!   95139463.0
# 13804  7.750000e+17                   Bedroom W/ Shared Bathroom  286256623.0
# 13805  7.750000e+17                                    Creek Zen  490347286.0
# 13806  7.750000e+17              The Flamingo - 1/1 pink retreat  203862347.0
# 13807  7.750000e+17                  Majic School Bus / Schoolie   23148741.0
#
#       host_name  neighbourhood_group  neighbourhood   latitude  longitude  \
# 13803  Felicity                  NaN        78705.0  30.283945 -97.749639
# 13804     Maris                  NaN        78724.0  30.310313 -97.652324
# 13805      Oleg                  NaN        78723.0  30.319973 -97.676901
# 13806     First                  NaN        78751.0  30.303751 -97.716428
# 13807   Stewart                  NaN        78704.0  30.258628 -97.784257
#
# ...

# %%
#print the number of missing values for all the columns
print(austin_df.isna().sum())
# Out:
# id                                    3
# name                                  3
# host_id                               3
# host_name                             5
# neighbourhood_group               13808
# neighbourhood                         3
# latitude                              3
# longitude                             3
# room_type                             3
# price                                 3
# minimum_nights                        3
# number_of_reviews                     3
# last_review                        2863
# reviews_per_month                  2863
# calculated_host_listings_count        3
# availability_365                      3
# number_of_reviews_ltm                 3
# license                           13808
# dtype: int64

# %%
# Remove 'license' and 'neighbourhood_group' columns
df_cleaned = austin_df.drop(columns=['license', 'neighbourhood_group'])

# Now, you can check for missing values in the cleaned DataFrame
missing_values_cleaned = df_cleaned.isnull().sum()
print(missing_values_cleaned)
# Out:
# id                                   3
# name                                 3
# host_id                              3
# host_name                            5
# neighbourhood                        3
# latitude                             3
# longitude                            3
# room_type                            3
# price                                3
# minimum_nights                       3
# number_of_reviews                    3
# last_review                       2863
# reviews_per_month                 2863
# calculated_host_listings_count       3
# availability_365                     3
# number_of_reviews_ltm                3
# dtype: int64

# %%
##I defined the NOIR datatypes that is what columns are what datatype, using python and pandas 
# loop over the columns in the DataFrame and determine their NOIR data type
for col in austin_df.columns:
    dtype = str(austin_df[col].dtype)
    if CategoricalDtype.is_dtype(austin_df[col]):
        dtype = 'Nominal'
    elif austin_df[col].dtype == int:
        dtype = 'Ordinal' if austin_df[col].nunique() < 10 else 'Integer'
    elif austin_df[col].dtype == float:
        dtype = 'Ratio'
    print(col + ': ' + dtype)
# Out:
# id: Ratio
# name: object
# host_id: Ratio
# host_name: object
# neighbourhood_group: Ratio
# neighbourhood: Ratio
# latitude: Ratio
# longitude: Ratio
# room_type: object
# price: Ratio
# minimum_nights: Ratio
# number_of_reviews: Ratio
# last_review: object
# reviews_per_month: Ratio
# calculated_host_listings_count: Ratio
# availability_365: Ratio
# number_of_reviews_ltm: Ratio
# license: Ratio

# %%
import pandas as pd

# Assuming df is your DataFrame 
# For example:
# df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# Export DataFrame to CSV
df_cleaned.to_csv('C:/Users/bharg/OneDrive/Documents/SPRING 2024/AIT 614/PROJECT/finaldatacleaned.csv', index=False)
